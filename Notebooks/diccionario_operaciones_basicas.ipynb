# %% [markdown]
# # DICCIONARY

# %% [markdown]
# ![Common dictionary literals and oparations](./images/CommonDictionary.png)

# %% [markdown]
# # Basic Dicionary Oprations

# %%
D = {'spam': 2, 'ham': 1, 'eggs': 3}
D
# Out:
# {'spam': 2, 'ham': 1, 'eggs': 3}

# %%
D['spam'] #Order "scrambled"
# Out:
# 2

# %% [markdown]
# The built-in len function works on dictionaries

# %%
len(D)
# Out:
# 3

# %%
'ham' in D
# Out:
# True

# %%
list(D.keys()) #create a new list of D's keys
# Out:
# ['spam', 'ham', 'eggs']

# %% [markdown]
# ## Changing Dictionaries in Place

# %%
D
# Out:
# {'spam': 2, 'ham': 1, 'eggs': 3}

# %%
D['ham'] = ['grill', 'bake', 'fry'] 
D
# Out:
# {'spam': 2, 'ham': ['grill', 'bake', 'fry'], 'eggs': 3}

# %%
del D['eggs']
D
# Out:
# {'spam': 2, 'ham': ['grill', 'bake', 'fry']}

# %%
D['brunch'] = 'Bacon' #create a new entry
D
# Out:
# {'spam': 2, 'ham': ['grill', 'bake', 'fry'], 'brunch': 'Bacon'}

# %% [markdown]
# ## More Dictionary Methods

# %% [markdown]
# The dictionary values and items methods return all of the dictionary’s values and (key,value) pair tuples

# %%
D = {'spam': 2, 'ham': 1, 'eggs': 3}
list(D.values())
# Out:
# [2, 1, 3]

# %%
list(D.items())
# Out:
# [('spam', 2), ('ham', 1), ('eggs', 3)]

# %%
D.get('spam') #key is there
# Out:
# 2

# %%
print(D.get('toast')) #key is missing
# Out:
# None

# %%
D.get('toast', 88) #example
# Out:
# 88

# %% [markdown]
# Update: merges the keys and values of one dictionary into another, blindly
# overwriting values of the same key if there’s a clash

# %%
D2 = {'toast':4, 'muffin':5}
D.update(D2)
D
# Out:
# {'spam': 2, 'ham': 1, 'eggs': 3, 'toast': 4, 'muffin': 5}

# %% [markdown]
# ".pop": method deletes a key from a dictionary and returns the value it had

# %%
D.pop('muffin')
# Out:
# 5

# %%
D.pop('toast')
# Out:
# 4

# %%
D
# Out:
# {'spam': 2, 'ham': 1, 'eggs': 3}

# %%
#pop a list by position
L = ['aa', 'bb', 'cc', 'dd']
L.pop() #delete and return from the end
# Out:
# 'dd'

# %%
L
# Out:
# ['aa', 'bb', 'cc']

# %%
L.pop(1) #delete from a specific posicion
# Out:
# 'bb'

# %%
L
# Out:
# ['aa', 'cc']

# %% [markdown]
# ### Example: Movie Database

# %%
table = {'1979': 'LIfe of Brian',
         '1975': 'Holy Grail',
         '1983': 'The Meaning of Life'}

# %%
for year in table:
    print(year + '\t' + table[year]) #Same as: for year in table.keys()
#  If needed, you can index from key to value inside the for loop as you go
# Out:
# 1979	LIfe of Brian
# 1975	Holy Grail
# 1983	The Meaning of Life

# %% [markdown]
# Preview: Mapping values to keys

# %%
table = {'Holy Grail':          '1975',
         'Lige of Brian':       '1979',
         'The Meaning of Life': '1983'}

# %%
table['Holy Grail']
# Out:
# '1975'

# %%
list(table.items())
# Out:
# [('Holy Grail', '1975'),
#  ('Lige of Brian', '1979'),
#  ('The Meaning of Life', '1983')]

# %%
[title for (title, year) in table.items() if year == '1975']
# Out:
# ['Holy Grail']

# %%
K = 'Holy Grail'

# %%
table[K]
# Out:
# '1975'

# %%
V = '1975'

# %%
[key for (key, value) in table.items() if value == V]
# Out:
# ['Holy Grail']

# %%
[key for key in table.keys() if table[key] == V]
# Out:
# ['Holy Grail']

# %% [markdown]
# ## Dictionary Usage Notes

# %% [markdown]
# <b>Sequence operations don’t work.</b> Dictionaries are mappings, not sequences; concatenation
# (an ordered joining) and slicing (extracting a contiguous section) simply don’t ap-
# ply.

# %% [markdown]
# <b>Assigning to new indexes adds entries.</b>

# %% [markdown]
# <b>Keys need not always be strings.</b>  immutable objects work just as well integers  Tuples dates and IP addresses User-defined class instance objects the proper protocol methods;  Mutable objects such as lists, sets, and other dictionaries don’t work as keys,
# but are allowed as values.

# %% [markdown]
# ### Integer keys

# %%
D = {}
D[99] = 'spam'
D[99]
# Out:
# 'spam'

# %%
D
# Out:
# {99: 'spam'}

# %% [markdown]
# Example

# %%
table = {1975: 'Holy Grail',
         1979: 'Life of Brian',
         1983: 'The Meaning of Life'}
table[1975]
# Out:
# 'Holy Grail'

# %%
list(table.items())
# Out:
# [(1975, 'Holy Grail'), (1979, 'Life of Brian'), (1983, 'The Meaning of Life')]

# %% [markdown]
# ### Tuple keys

# %%
Matrix = {}
Matrix [(2, 3, 4)] = 88
Matrix[(7, 8, 9)] = 99
X = 2; Y = 3; Z = 4
Matrix[(X, Y, Z)]
Matrix
# Out:
# {(2, 3, 4): 88, (7, 8, 9): 99}

# %% [markdown]
# ### Avoiding missing-key errors

# %%
if (2, 3, 6) in Matrix:
    print(Matrix[(2, 3, 6)])
else:
    print(0)
# Out:
# 0

# %%
try:
    print(Matrix[2, 3, 6])
except KeyError:
    print(0)
# Out:
# 0

# %%
Matrix.get((2, 3, 4), 0)
# Out:
# 88

# %%
Matrix.get((2, 3, 6), 0)
# Out:
# 0

# %% [markdown]
# ### Nesting in dictionaries

# %%
rec = {}
rec['name'] = 'Bob'
rec['age'] = 40.5
rec['job'] = 'developer/manager'

print(rec['name'])
# Out:
# Bob

# %%
rec = {'name': 'Bob',
       'jobs': ['developer','manager'],
       'web': 'www.bobs.org/˜Bob',
       'home': {'state': 'Overworked', 'zip': 12345}}

rec['name']
# Out:
# 'Bob'

# %%
rec['jobs']
# Out:
# ['developer', 'manager']

# %%
rec['jobs'][1]
# Out:
# 'manager'

# %%
rec['home']['zip']
# Out:
# 12345

# %% [markdown]
# database collection coded as a list or dictionary

# %%
db = []
db.append(rec)
db.append("other") # is not defined 'other'
db[0]['jobs']
# A list "database"
# Out:
# ['developer', 'manager']

# %%
db = {}
db['bob'] = rec
db['sue'] = "other" # is not defined 'other'
db['bob']['jobs']
 # A dictionary "database"
# Out:
# ['developer', 'manager']

# %% [markdown]
# ## Other Ways to Make Dictionaries

# %%
D = {}
D['name'] = 'Bob'
D['age'] = 40

dict(name='Bob', age=40) #dict keyword argument form
# Out:
# {'name': 'Bob', 'age': 40}

# %%
dict([('name', 'Bob'), ('age', 40)]) # dict key/value tuples form
# Out:
# {'name': 'Bob', 'age': 40}

# %%
dict(zip(keylist, valuelist))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 dict(zip(keylist, valuelist))
#
# NameError: name 'keylist' is not defined

# %%
dict.fromkeys(['a', 'b'], 0)
# Out:
# {'a': 0, 'b': 0}

# %% [markdown]
# -> Why You Will Care: Dictionaries Versus Lists

# %% [markdown]
# Example to represetation = to list a dictionary

# %%
L = ['Bob', 40.5, ['dev', 'mgr']]
L[0]
# Out:
# 'Bob'

# %%
L[1]
# Out:
# 40.5

# %%
L[2][1]
# Out:
# 'mgr'

# %% [markdown]
# In dictionary

# %%
D = {'name': 'Bob', 'age': 40.5, 'jobs': ['dev', 'mgr']}
D['name']
# Out:
# 'Bob'

# %%
D['age']
# Out:
# 40.5

# %%
D['jobs'][1]
# Out:
# 'mgr'

# %% [markdown]
# For variety

# %%
D = dict(name='Bob', age=40.5, jobs=['dev', 'mgr'])
D['name']
# Out:
# 'Bob'

# %%
D['jobs'].remove('mgr')
D
# Out:
# {'name': 'Bob', 'age': 40.5, 'jobs': ['dev']}

# %% [markdown]
# for fast lookups when there is no associated value

# %%
D={}
D['state1'] = True
'state1' in D
# Out:
# True

# %%
S = set()
S.add('state1')
'state1' in S
# Out:
# True

# %% [markdown]
# ## Dictionary Changes in Python 3.X and 2.7

# %% [markdown]
# ### Dictionary comprehensions in 3.X and 2.7

# %%
list(zip(['a', 'b', 'c'], [1, 2, 3]))  #Zip together keys and values
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %%
D = dict(zip(['a', 'b', 'c'], [1, 2, 3]))  #Make a dict from zip result
D
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# dictionary comprehension expression

# %%
D = {k: v for (k, v) in zip(['a', 'b', 'c'], [1, 2, 3])}
D
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# As well, and keys can be computed with expressions

# %%
 D = {x: x ** 2 for x in [1, 2, 3, 4]} # Or: range(1, 5)
D
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
D = {c: c * 4 for c in 'SPAM'} # Loop over any iterable
D
# Out:
# {'S': 'SSSS', 'P': 'PPPP', 'A': 'AAAA', 'M': 'MMMM'}

# %%
D = {c.lower(): c + '!' for c in ['SPAM', 'EGGS', 'HAM']}
D
# Out:
# {'spam': 'SPAM!', 'eggs': 'EGGS!', 'ham': 'HAM!'}

# %% [markdown]
# for initializing dictionaries from keys lists

# %%
D = dict.fromkeys(['a', 'b', 'c'], 0)  # Initialize dict from keys
D
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
 D = {k:0 for k in ['a', 'b', 'c']} #  Same, but with a comprehension
D
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
D = dict.fromkeys('spam') #ther iterables, default value
D
# Out:
# {'s': None, 'p': None, 'a': None, 'm': None}

# %%
D = {k: None for k in 'spam'}
D
# Out:
# {'s': None, 'p': None, 'a': None, 'm': None}

# %% [markdown]
# ### Dictionary views in 3.X (and 2.7 via new methods)

# %%
D = dict(a=1, b=2, c=3)
D
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
K = D.keys()  #Makes a view object in 3.X, not a list
K
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
list(K) # Force a real list in 3.X if needed
# Out:
# ['a', 'b', 'c']

# %%
V = D.values()   #Ditto for values and items views
V
# Out:
# dict_values([1, 2, 3])

# %%
list(V)
# Out:
# [1, 2, 3]

# %%
D.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
list(D.items())
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %%
K[0] # List operations fail unless converted
# Out:
#   Cell In[32], line 1
#     "K[0]"" # List operations fail unless converted
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
list(K)[0]
# Out:
# 'a'

# %%
for k in D.keys(): print(k) # Iterators used automatically in loops
# Out:
# a
# b
# c

# %% [markdown]
# They dynamically reflect future changes made to the dictionary after the view
# object has been created

# %%
D = {'a': 1, 'b': 2, 'c': 3}
D
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
K = D.keys()
V = D.values()
list(K) #Views maintain same order as dictionary
# Out:
# ['a', 'b', 'c']

# %%
list(V)
# Out:
# [1, 2, 3]

# %%
del D['b'] # Change the dictionary in place
D
# Out:
# {'a': 1, 'c': 3}

# %%
list(K)
# Out:
# ['a', 'c']

# %%
list(V)
# Out:
# [1, 3]

# %% [markdown]
# ### Dictioanry views and sets

# %%
K, V
# Out:
# (dict_keys(['a', 'c']), dict_values([1, 3]))

# %%
K | {'x': 4} # Keys (and some items) views are set-like
# Out:
# {'a', 'c', 'x'}

# %%
V & {'x': 4}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 V & {'x': 4}
#
# TypeError: unsupported operand type(s) for &: 'dict_values' and 'dict'

# %%
V & {'x': 4}.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 V & {'x': 4}.values()
#
# TypeError: unsupported operand type(s) for &: 'dict_values' and 'dict_values'

# %% [markdown]
# In set operations, views may be mixed with other views, sets, and dictionaries; dic-
# tionaries are treated the same as their keys

# %%
D = {'a': 1, 'b': 2, 'c': 3}
D.keys() & D.keys() # Intersect keys views
# Out:
# {'a', 'b', 'c'}

# %%
D.keys() & {'b'} # Intersect keys and set
# Out:
# {'b'}

# %%
D.keys() & {'b': 1} # Intersect keys and dict
# Out:
# {'b'}

# %%
D.keys() | {'b', 'c', 'd'} # Union keys and set
# Out:
# {'a', 'b', 'c', 'd'}

# %% [markdown]
# Items views are set-like too if they are hashable—that is, if they contain only immutable
# objects

# %%
D = {'a': 1}
list(D.items()) # Items set-like if hashable
# Out:
# [('a', 1)]

# %%
D.items() | D.keys() # Union view and view
# Out:
# {('a', 1), 'a'}

# %%
D.items() | D  # dict treated same as its keys
# Out:
# {('a', 1), 'a'}

# %%
 D.items() | {('c', 3), ('d', 4)} # Set of key/value pairs
# Out:
# {('a', 1), ('c', 3), ('d', 4)}

# %%
dict(D.items() | {('c', 3), ('d', 4)}) #dict accepts iterable sets too
# Out:
# {'d': 4, 'a': 1, 'c': 3}

# %% [markdown]
# ### Sorting dictionary keys in 3.X

# %%
D = {'a': 1, 'b': 2, 'c': 3}
D
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
Ks = D.keys() # Sorting a view object doesn't work!
Ks.sort()  # AttributeError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 2
#       1 Ks = D.keys()
# ----> 2 Ks.sort()
#
# AttributeError: 'dict_keys' object has no attribute 'sort'

# %% [markdown]
# on either a keys view or the dictionary itself

# %%
Ks = list(Ks) # Force it to be a list and then sort
Ks.sort()
for k in Ks: print(k, D[k])  # 2.X: omit outer parens in prints
# Out:
# a 1
# b 2
# c 3

# %%
D
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
Ks = D.keys()                       # Or you can use sorted() on the keys
for k in sorted(Ks): print(k, D[k]) # sorted() accepts any iterable
                                    # sorted() returns its result
# Out:
# a 1
# b 2
# c 3

# %% [markdown]
# Using the dictionary’s keys iterator is probably preferable in 3.X, and works
# in 2.X

# %%
D # Better yet, sort the dict directly
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
for k in sorted(D): print(k, D[k]) # dict iterators return keys
# Out:
# a 1
# b 2
# c 3

# %% [markdown]
# ### Dictionary magnitude comparisons no longer work in 3.X

# %% [markdown]
# Secondly, while in Python 2.X dictionaries may be compared for relative magnitude
# directly with <, >, and so on, in Python 3.X

# %%
sorted(D1.items()) < sorted(D2.items()) # Like 2.X D1 < D2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 sorted(D1.items()) < sorted(D2.items()) # Like 2.X D1 < D2
#
# NameError: name 'D1' is not defined

# %% [markdown]
# ### The has_key method is dead in 3.X: Long live in!

# %%
D
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
D.has_key('c') # 2.X only: True/False
               # attributteError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 D.has_key('c') # 2.X only: True/False
#
# AttributeError: 'dict' object has no attribute 'has_key'

# %%
'c' in D # Required in 3.X
# Out:
# True

# %%
'x' in D # Preferred in 2.X today
# Out:
# False

# %%
if 'c' in D: print('present', D['c']) # Branch on result
# Out:
# present 3

# %%
 print(D.get('c')) # Fetch with default
# Out:
# 3

# %%
print(D.get('x'))
# Out:
# None

# %%
if D.get('c') != None: print('present', D['c']) # Another option
# Out:
# present 3
